# %%
import numpy as np
import pandas as pd
from sklearn import linear_model # packages for the logistic regression function to plot the logistic regression 
from sklearn.linear_model import LogisticRegression # packages for the logistic regression function to plot the logistic regression 
from scipy import stats
from scipy import signal
from scipy.stats.stats import pearsonr # Pearson's correlation
from pandas.core.frame import DataFrame as DF
from copy import copy as copy
import operator as operator
import pylab
import scipy.io as spi
import seaborn as sns; 
# Show graphs in Notebook
# %matplotlib inline

# linking to files in notebooks
from IPython.display import FileLink, FileLinks

# Plotting tools
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
# Useful to quickly extract csv files
import glob
import os
from random import *

# %%
# Extract data

# %%
username = input("Enter username:")
print("Username is: " + username)
# Out:
# Enter username: pilot3
# Username is: pilot3

# %%
username
# Out:
# 'pilot3'

# %%
choiceNameFrames1 = glob.glob('/Users/pradyumna/Google Drive/BdM Projects/pupilPEB2021/Pilots/pilot data/'+str(username)+'/RESULTS_FILE.txt')

# %%
choiceNameFrames1
# Out:
# ['/Users/pradyumna/Google Drive/BdM Projects/pupilPEB2021/Pilots/pilot data/pilot3/RESULTS_FILE.txt']

# %%
choiceFrameAll = pd.read_csv(choiceNameFrames1[0],delim_whitespace=True) 
choiceFrameAll
# Out:
#     Session_Name_  Trial_Index_     expcond  trialn  noisecond  \
# 0          pilot3            21  Experiment     194          1
# 1          pilot3            22  Experiment     177          1
# 2          pilot3            23  Experiment      96          1
# 3          pilot3            24  Experiment     174          1
# 4          pilot3            25  Experiment      25          1
# ..            ...           ...         ...     ...        ...
# 235        pilot3           256  Experiment     239          1
# 236        pilot3           257  Experiment      43          1
# 237        pilot3           258  Experiment      61          1
# 238        pilot3           259  Experiment     125          1
# 239        pilot3           260  Experiment     207          1
#
#                leftitm           rightitm  whichfirstopt  noiseinl  noiseinr  \
# 0    L_Noise_0_954.wav  R_Noise_0_918.wav              2         0         0
# 1    L_Noise_0_972.wav  R_Noise_0_900.wav              1         0         0
# 2    L_Noise_0_742.wav  R_Noise_0_756.wav              1         0         0
# 3    L_Noise_0_954.wav  R_Noise_0_918.wav              1         0         0
# 4    L_Noise_0_510.wav  R_Noise_0_500.wav              2         0         0
# ..                 ...                ...            ...       ...       ...
# 235  L_Noise_0_972.wav  R_Noise_0_936.wav              2         0         0
# 236  L_Noise_0_500.wav  R_Noise_0_530.wav              1         0         0
# 237  L_Noise_0_500.wav  R_Noise_0_510.wav              2         0         0
# 238  L_Noise_0_714.wav  R_Noise_0_700.wav              1         0         0
# 239  L_Noise_0_918.wav  R_Noise_0_954.wav              1         0         0
#
#      ...  freqr  frame     Frame_Name Slider_X  Choice_SND1_Time   CONF  \
# 0    ...    918      1      like2.png      522         538129.19  51.67
# 1    ...    900      1      like2.png      612         551570.43  66.67
# 2    ...    756      1      like2.png      522         564466.70  51.67
# 3    ...    918      1      like2.png      612         577794.73  66.67
# 4    ...    500      1      like2.png      612         592010.39  66.67
# ..   ...    ...    ...            ...      ...               ...    ...
# 235  ...    936      2  aversion2.png      212        4411475.52   0.00
# 236  ...    530      2  aversion2.png      612        4421643.95  66.67
# 237  ...    510      2  aversion2.png      432        4435836.91  36.67
# 238  ...    700      2  aversion2.png      432        4446316.52  36.67
# 239  ...    954      2  aversion2.png      402        4458972.88  31.67
#
#      CONF_RT  Choice_SND1 Choice_SND1_RT  TRIAL_N_LIVE
# 0       2921            z           1876             1
# 1       3158            z           1784             2
# 2       3843            z           1614             3
# 3       4615            z           1409             4
# 4       5742            m           1108             5
# ..       ...          ...            ...           ...
# 235     1698            m            629           236
# 236     4540            m            864           237
# 237     2038            z           1857           238
# 238     4122            m            787           239
# 239     1833            m            577           240
#
# [240 rows x 21 columns]

# %%
choiceFrameAll.columns
# Out:
# Index(['Session_Name_', 'Trial_Index_', 'expcond', 'trialn', 'noisecond',
#        'leftitm', 'rightitm', 'whichfirstopt', 'noiseinl', 'noiseinr', 'freql',
#        'freqr', 'frame', 'Frame_Name', 'Slider_X', 'Choice_SND1_Time', 'CONF',
#        'CONF_RT', 'Choice_SND1', 'Choice_SND1_RT', 'TRIAL_N_LIVE'],
#       dtype='object')

# %%
Correct = []
for i in range(len(choiceFrameAll)):
    if choiceFrameAll.frame[i] == 1:
        if (choiceFrameAll.Choice_SND1[i] == 'm' and (choiceFrameAll.freql[i] <= choiceFrameAll.freqr[i])) or (choiceFrameAll.Choice_SND1[i] == 'z' and (choiceFrameAll.freql[i] >= choiceFrameAll.freqr[i])):
            Correct.append(1)
        else:
            Correct.append(0)
    if choiceFrameAll.frame[i] == 2:
        if (choiceFrameAll.Choice_SND1[i] == 'z' and (choiceFrameAll.freql[i] <= choiceFrameAll.freqr[i])) or (choiceFrameAll.Choice_SND1[i] == 'm' and (choiceFrameAll.freql[i] >= choiceFrameAll.freqr[i])):
            Correct.append(1)
        else:
            Correct.append(0)

choiceFrameAll["correct"] = Correct

# %%
choiceFrameAll
# Out:
#     Session_Name_  Trial_Index_     expcond  trialn  noisecond  \
# 0          pilot3            21  Experiment     194          1
# 1          pilot3            22  Experiment     177          1
# 2          pilot3            23  Experiment      96          1
# 3          pilot3            24  Experiment     174          1
# 4          pilot3            25  Experiment      25          1
# ..            ...           ...         ...     ...        ...
# 235        pilot3           256  Experiment     239          1
# 236        pilot3           257  Experiment      43          1
# 237        pilot3           258  Experiment      61          1
# 238        pilot3           259  Experiment     125          1
# 239        pilot3           260  Experiment     207          1
#
#                leftitm           rightitm  whichfirstopt  noiseinl  noiseinr  \
# 0    L_Noise_0_954.wav  R_Noise_0_918.wav              2         0         0
# 1    L_Noise_0_972.wav  R_Noise_0_900.wav              1         0         0
# 2    L_Noise_0_742.wav  R_Noise_0_756.wav              1         0         0
# 3    L_Noise_0_954.wav  R_Noise_0_918.wav              1         0         0
# 4    L_Noise_0_510.wav  R_Noise_0_500.wav              2         0         0
# ..                 ...                ...            ...       ...       ...
# 235  L_Noise_0_972.wav  R_Noise_0_936.wav              2         0         0
# 236  L_Noise_0_500.wav  R_Noise_0_530.wav              1         0         0
# 237  L_Noise_0_500.wav  R_Noise_0_510.wav              2         0         0
# 238  L_Noise_0_714.wav  R_Noise_0_700.wav              1         0         0
# 239  L_Noise_0_918.wav  R_Noise_0_954.wav              1         0         0
#
#      ...  frame     Frame_Name  Slider_X Choice_SND1_Time   CONF  CONF_RT  \
# 0    ...      1      like2.png       522        538129.19  51.67     2921
# 1    ...      1      like2.png       612        551570.43  66.67     3158
# 2    ...      1      like2.png       522        564466.70  51.67     3843
# 3    ...      1      like2.png       612        577794.73  66.67     4615
# 4    ...      1      like2.png       612        592010.39  66.67     5742
# ..   ...    ...            ...       ...              ...    ...      ...
# 235  ...      2  aversion2.png       212       4411475.52   0.00     1698
# 236  ...      2  aversion2.png       612       4421643.95  66.67     4540
# 237  ...      2  aversion2.png       432       4435836.91  36.67     2038
# 238  ...      2  aversion2.png       432       4446316.52  36.67     4122
# 239  ...      2  aversion2.png       402       4458972.88  31.67     1833
#
#      Choice_SND1  Choice_SND1_RT TRIAL_N_LIVE  correct
# 0              z            1876            1        1
# 1              z            1784            2        1
# 2              z            1614            3        0
# 3              z            1409            4        1
# 4              m            1108            5        0
# ..           ...             ...          ...      ...
# 235            m             629          236        1
# 236            m             864          237        0
# 237            z            1857          238        1
# 238            m             787          239        1
# 239            m             577          240        0
#
# [240 rows x 22 columns]

# %%
data_expHigh = choiceFrameAll.loc[(choiceFrameAll['frame'] == 1)] # 1 = high, 2 = low
data_expLow = choiceFrameAll.loc[(choiceFrameAll['frame'] == 2)] # 1 = high, 2 = low

# %%
accuracies = pd.DataFrame( columns = [])
accuracyH = []
accuracyL = []

accuracyH.append(choiceFrameAll.loc[(choiceFrameAll['frame'] == 1) ].correct.mean())
print('Accuracy High Pitch:  ' + str(accuracyH[0]))

accuracyL.append(choiceFrameAll.loc[(choiceFrameAll['frame'] == 2) ].correct.mean())
print('Accuracy Low Pitch:  ' + str(accuracyL[0]))

accuracies['high'] = accuracyH[0]
accuracies['low'] = accuracyL[0]
# Out:
# Accuracy High Pitch:  0.5416666666666666
# Accuracy Low Pitch:  0.5666666666666667
